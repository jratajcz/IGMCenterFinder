# %%
import numpy as np
import astropy
from astropy.table import Table
from astropy.io import fits
import os
import time
from astropy import units as u
from astropy.coordinates import SkyCoord
import matplotlib.pyplot as plt

# %%
hdu1 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_60.0_cut_-inf.fits")
hdu2 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_70.0_cut_-inf.fits")
hdu3 = fits.open("//home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_80.0_cut_-inf.fits")
hdu4 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_90.0_cut_-inf.fits")
hdu5 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_100.0_cut_-inf.fits")
hdu6 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_110.0_cut_-inf.fits")
hdu7 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_120.0_cut_-inf.fits")
hdu8 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_130.0_cut_-inf.fits")
hdu9 = fits.open("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/found_centers_r_140.0_cut_-inf.fits")

N_points = 1000
n_bins = 100


plt.hist(hdu1[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu2[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu3[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu4[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu5[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu6[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu7[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu8[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')
plt.hist(hdu9[1].data['wts'],range = (-30000,16000),bins=n_bins, histtype ='step')

plt.title('Distribution of Potential Center Weights')
plt.legend(["s = 60","s = 70","s = 80","s = 90","s = 100","s = 110","s = 120","s = 130","s = 140"])
plt.yscale("log")
plt.xlabel("Wts")
plt.ylabel("Count")
# Out:
# Text(0,0.5,'Count')

# %%
#Loads in all the density and centers grids
# a = density
# b = centers
# c =  Sum(W0*W1)

a1 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_140.0_no_cut.npy")
b1 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_140.0_no_cut.npy")
c1 = np.sum(a1*b1)
a2 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_135.0_no_cut.npy")
b2 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_135.0_no_cut.npy")
c2 = np.sum(a2*b2)
a3 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_130.0_no_cut.npy")
b3 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_130.0_no_cut.npy")
c3 = np.sum(a3*b3)
a4 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_125.0_no_cut.npy")
b4 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_125.0_no_cut.npy")
c4 = np.sum(a4*b4)
a5 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_120.0_no_cut.npy")
b5 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_120.0_no_cut.npy")
c5 = np.sum(a5*b5)
a6 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_115.0_no_cut.npy")
b6 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_115.0_no_cut.npy")
c6 = np.sum(a6*b6)
a7 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_105.0_no_cut.npy")
b7 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_105.0_no_cut.npy")
c7 = np.sum(a7*b7)
a8 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_100.0_no_cut.npy")
b8 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_100.0_no_cut.npy")
c8 = np.sum(a8*b8)
a9 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_95.0_no_cut.npy")
b9 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_95.0_no_cut.npy")
c9 = np.sum(a9*b9)
a10 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_90.0_no_cut.npy")
b10 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_90.0_no_cut.npy")
c10 = np.sum(a10*b10)
a11 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_85.0_no_cut.npy")
b11 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_85.0_no_cut.npy")
c11 = np.sum(a11*b11)
a12 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_80.0_no_cut.npy")
b12 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_80.0_no_cut.npy")
c12 = np.sum(a12*b12)
a13 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_75.0_no_cut.npy")
b13 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_75.0_no_cut.npy")
c13 = np.sum(a13*b13)
a14 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_70.0_no_cut.npy")
b14 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_70.0_no_cut.npy")
c14 = np.sum(a14*b14)
a15 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_65.0_no_cut.npy")
b15 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_65.0_no_cut.npy")
c15 = np.sum(a15*b15)
a16 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_60.0_no_cut.npy")
b16 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_60.0_no_cut.npy")
c16 = np.sum(a16*b16)
a17 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/density_grid_r_110.0_no_cut.npy")
b17 = np.load("/home/jratajcz/Desktop/CutDR16/centerfinder-master_old_2020/out__scratch_jratajcz_map_Stripe82_Tomographic/centers_grid_r_110.0_no_cut.npy")
c17 = np.sum(a17*b17)

# %%
xi = [c16,c15,c14,c13,c12,c11,c10,c9,c8,c7,c17,c6,c5,c4,c4,c2,c1]
s = []
s_squared = []
for i in range(60,145,5):
    s_squared.append(float(i**2))
for i in range(60,145,5):
    s.append(float(i))
    
s = np.asarray(s) #array of all s
xi = np.array(xi)#array of all xi
corr_func = s_squared*xi # convenentional plotting method

# %%
plt.plot(s,corr_func,color='Black', marker='o', linestyle='dashed',linewidth=2, markersize=2, label ="Data Stripe 82")
plt.xlabel("s [Mpc/h]")
plt.ylabel("\u03BE(s)")
plt.title('DR16 Stripe 82 2PCF')
plt.legend(loc = "upper right")
